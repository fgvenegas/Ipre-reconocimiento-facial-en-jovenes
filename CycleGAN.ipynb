# %%
# !pip3 install scipy==1.1.0
# Out:
# Collecting scipy==1.1.0
#   Downloading https://files.pythonhosted.org/packages/a8/0b/f163da98d3a01b3e0ef1cab8dd2123c34aee2bafbb1c5bffa354cc8a1730/scipy-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 26.1MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.6/dist-packages (from scipy==1.1.0) (1.17.3)
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
#   Found existing installation: scipy 1.3.1
#     Uninstalling scipy-1.3.1:
#       Successfully uninstalled scipy-1.3.1
# Successfully installed scipy-1.1.0

# %%
import os
import time
from glob import glob
import tensorflow as tf
import numpy as np
from collections import namedtuple
import shutil

from google.colab import drive
drive.mount('/content/drive')

import tensorflow.contrib.slim as slim
import math
import pprint
import scipy.misc
import copy
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Utils

# %%
def discriminator(image, options, reuse=False, name="discriminator"):

    with tf.variable_scope(name):
        # image is 256 x 256 x input_c_dim
        if reuse:
            tf.get_variable_scope().reuse_variables()
        else:
            assert tf.get_variable_scope().reuse is False

        h0 = lrelu(conv2d(image, options.df_dim, name='d_h0_conv'))
        # h0 is (128 x 128 x self.df_dim)
        h1 = lrelu(instance_norm(conv2d(h0, options.df_dim*2, name='d_h1_conv'), 'd_bn1'))
        # h1 is (64 x 64 x self.df_dim*2)
        h2 = lrelu(instance_norm(conv2d(h1, options.df_dim*4, name='d_h2_conv'), 'd_bn2'))
        # h2 is (32x 32 x self.df_dim*4)
        h3 = lrelu(instance_norm(conv2d(h2, options.df_dim*8, s=1, name='d_h3_conv'), 'd_bn3'))
        # h3 is (32 x 32 x self.df_dim*8)
        h4 = conv2d(h3, 1, s=1, name='d_h3_pred')
        # h4 is (32 x 32 x 1)
        return h4

def generator_resnet(image, options, reuse=False, name="generator"):

    with tf.variable_scope(name):
        # image is 256 x 256 x input_c_dim
        if reuse:
            tf.get_variable_scope().reuse_variables()
        else:
            assert tf.get_variable_scope().reuse is False

        def residule_block(x, dim, ks=3, s=1, name='res'):
            p = int((ks - 1) / 2)
            y = tf.pad(x, [[0, 0], [p, p], [p, p], [0, 0]], "REFLECT")      # padding은 양옆 위아래로 1씩만.

            # instance_norm은 nomalization.
            y = instance_norm(conv2d(y, dim, ks, s, padding='VALID', name=name+'_c1'), name+'_bn1')
            y = tf.pad(tf.nn.relu(y), [[0, 0], [p, p], [p, p], [0, 0]], "REFLECT")
            y = instance_norm(conv2d(y, dim, ks, s, padding='VALID', name=name+'_c2'), name+'_bn2')
            return y + x


        c0 = tf.pad(image, [[0, 0], [3, 3], [3, 3], [0, 0]], "REFLECT")     # 위 아래 가로 세로로 패딩 3씩.
        c1 = tf.nn.relu(instance_norm(conv2d(c0, options.gf_dim, 7, 1, padding='VALID', name='g_e1_c'), 'g_e1_bn'))
        c2 = tf.nn.relu(instance_norm(conv2d(c1, options.gf_dim*2, 3, 2, name='g_e2_c'), 'g_e2_bn'))
        c3 = tf.nn.relu(instance_norm(conv2d(c2, options.gf_dim*4, 3, 2, name='g_e3_c'), 'g_e3_bn'))        # 64 *64

        # define G network with 9 resnet blocks
        # 총 cnn 18층.
        r1 = residule_block(c3, options.gf_dim*4, name='g_r1')
        r2 = residule_block(r1, options.gf_dim*4, name='g_r2')
        r3 = residule_block(r2, options.gf_dim*4, name='g_r3')
        r4 = residule_block(r3, options.gf_dim*4, name='g_r4')
        r5 = residule_block(r4, options.gf_dim*4, name='g_r5')
        r6 = residule_block(r5, options.gf_dim*4, name='g_r6')
        r7 = residule_block(r6, options.gf_dim*4, name='g_r7')
        r8 = residule_block(r7, options.gf_dim*4, name='g_r8')
        r9 = residule_block(r8, options.gf_dim*4, name='g_r9')

        d1 = deconv2d(r9, options.gf_dim*2, 3, 2, name='g_d1_dc')
        d1 = tf.nn.relu(instance_norm(d1, 'g_d1_bn'))
        d2 = deconv2d(d1, options.gf_dim, 3, 2, name='g_d2_dc')
        d2 = tf.nn.relu(instance_norm(d2, 'g_d2_bn'))
        d2 = tf.pad(d2, [[0, 0], [3, 3], [3, 3], [0, 0]], "REFLECT")

        # 위에 패딩을 해놨고 7 by 7 필터사용.
        pred = tf.nn.tanh(conv2d(d2, options.output_c_dim, 7, 1, padding='VALID', name='g_pred_c'))



        return pred

def abs_criterion(in_, target):
    return tf.reduce_mean(tf.abs(in_ - target))

def mae_criterion(in_, target):
    return tf.reduce_mean((in_-target)**2)

def sce_criterion(logits, labels):
    return tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=labels))

# 이미지를 풀링
class ImagePool(object):
    def __init__(self, maxsize=50):
        self.maxsize = maxsize
        self.num_img = 0
        self.images = []

    def __call__(self, image):
        if self.maxsize <= 0:
            return image
        if self.num_img < self.maxsize:
            self.images.append(image)
            self.num_img += 1
            return image
        if np.random.rand() > 0.5:
            idx = int(np.random.rand()*self.maxsize)
            tmp1 = copy.copy(self.images[idx])[0]
            self.images[idx][0] = image[0]
            idx = int(np.random.rand()*self.maxsize)
            tmp2 = copy.copy(self.images[idx])[1]
            self.images[idx][1] = image[1]
            return [tmp1, tmp2]
        else:
            return image

"""=========== 모델 만들 때 필요한 함수 =============="""

def instance_norm(input, name="instance_norm"):
    with tf.variable_scope(name):
        depth = input.get_shape()[3]            # 채널 수.

        # 평균 1, 표준편차 0.02 nomal distribution, 즉 채널 수 갯수만큼 변수 생성.
        scale = tf.get_variable("scale", [depth], initializer=tf.random_normal_initializer(1.0, 0.02, dtype=tf.float32))

        #채널 수 갯수 만큼 변수 생성.
        offset = tf.get_variable("offset", [depth], initializer=tf.constant_initializer(0.0))

        mean, variance = tf.nn.moments(input, axes=[1,2], keep_dims=True)       # 가로, 세로에 대해서 평균과 분산을 구하기.
        epsilon = 1e-5
        inv = tf.rsqrt(variance + epsilon)
        normalized = (input-mean)*inv
        return scale*normalized + offset

def conv2d(input_, output_dim, ks=4, s=2, stddev=0.02, padding='SAME', name="conv2d"):
    with tf.variable_scope(name):       # 앞에 conv2d가 붙음.
        # output_dim == 필터수. ks == 커널 사이즈.(4 x4) s==스트라이드, 활성 함수 없음.
        # 이미지 사이즈 가로 세로 각각 0.5배
        return slim.conv2d(input_, output_dim, ks, s, padding=padding, activation_fn=None,
                            weights_initializer=tf.truncated_normal_initializer(stddev=stddev),
                            biases_initializer=None)

def deconv2d(input_, output_dim, ks=4, s=2, stddev=0.02, name="deconv2d"):
    with tf.variable_scope(name):
        # 이미지 사이즈 가로 세로 각각 2배됨.
        return slim.conv2d_transpose(input_, output_dim, ks, s, padding='SAME', activation_fn=None,
                                    weights_initializer=tf.truncated_normal_initializer(stddev=stddev),
                                    biases_initializer=None)

def lrelu(x, leak=0.2, name="lrelu"):
    return tf.maximum(x, leak*x)

"""======================== 여기는 모델외 모듈들 .=================================="""

_imread = scipy.misc.imread

def load_test_data(image_path, fine_size=256):
    img = imread(image_path)
    img = scipy.misc.imresize(img, [fine_size, fine_size])
    img = img/127.5 - 1         # -1에서 1사이로 맞추려고.
    return img

def load_train_data(image_path, load_size=286, fine_size=256, is_testing=False):
    img_A = imread(image_path[0])
    img_B = imread(image_path[1])

    if not is_testing:  # 훈련 중
        img_A = scipy.misc.imresize(img_A, [load_size, load_size])
        img_B = scipy.misc.imresize(img_B, [load_size, load_size])
        h1 = int(np.ceil(np.random.uniform(1e-2, load_size-fine_size))) # 1에서 load_size-fine_size 사이의 값 하나.
        w1 = int(np.ceil(np.random.uniform(1e-2, load_size-fine_size)))
        img_A = img_A[h1:h1+fine_size, w1:w1+fine_size]         # 이미지를 랜덤하게 컷팅... why??
        img_B = img_B[h1:h1+fine_size, w1:w1+fine_size]

        if np.random.random() > 0.5:                # 50프로 확률로 이미지 뒤집기
            img_A = np.fliplr(img_A)
            img_B = np.fliplr(img_B)

    else:   # 테스트 중!
        img_A = scipy.misc.imresize(img_A, [fine_size, fine_size])
        img_B = scipy.misc.imresize(img_B, [fine_size, fine_size])

    img_A = img_A/127.5 - 1.
    img_B = img_B/127.5 - 1.

    img_AB = np.concatenate((img_A, img_B), axis=2)
    # img_AB shape: (fine_size, fine_size, input_c_dim + output_c_dim)
    return img_AB

def get_image(image_path, image_size, is_crop=True, resize_w=64, is_grayscale = False):
    return transform(imread(image_path, is_grayscale), image_size, is_crop, resize_w)

def save_images(images, size, image_path):
    return imsave(inverse_transform(images), size, image_path)

def imread(path, is_grayscale = False):
    if (is_grayscale):
        return _imread(path, flatten=True).astype(np.float)
    else:
        return _imread(path, mode='RGB').astype(np.float)

def merge_images(images, size):
    return inverse_transform(images)

def merge(images, size):
    h, w = images.shape[1], images.shape[2]
    img = np.zeros((h * size[0], w * size[1], 3))
    for idx, image in enumerate(images):
        i = idx % size[1]
        j = idx // size[1]
        img[j*h:j*h+h, i*w:i*w+w, :] = image

    return img

def imsave(images, size, path):
    return scipy.misc.imsave(path, merge(images, size))


def center_crop(x, crop_h, crop_w,
                resize_h=64, resize_w=64):
  if crop_w is None:
    crop_w = crop_h
  h, w = x.shape[:2]
  j = int(round((h - crop_h)/2.))
  i = int(round((w - crop_w)/2.))
  return scipy.misc.imresize(
      x[j:j+crop_h, i:i+crop_w], [resize_h, resize_w])

def transform(image, npx=64, is_crop=True, resize_w=64):

    if is_crop:
        cropped_image = center_crop(image, npx, resize_w=resize_w)
    else:
        cropped_image = image
    return np.array(cropped_image)/127.5 - 1.

def inverse_transform(images):
    return (images+1.)/2.

# %% [markdown]
# ## Main

# %%
class cyclegan():
    def __init__(self, sess, checkpoint_dir, test_dir, dataset_dir, which_direction):
        self.sess = sess
        self.batch_size = 1           # 배치 사이즈
        self.image_size = 256            # 잘리는 사이즈
        self.input_c_dim = 3            # 인풋 이미지 채널
        self.output_c_dim = 3          # 아웃풋 이미지 채널
        self.L1_lambda = 10.0
        self.fine_size = 256
        self.ngf = 64         # G의 첫번째 conv 레이어 필터수
        self.ndf = 64         # F의 첫번째 conv 레이어 필터수
        self.output_nc = 3
        self.max_size = 50
        self.beta1 = 0.5        # adam 두번째 옵션
        self.epoch = 200        # 200에폭 돌려라.
        self.epoch_step = 100   # lr를 줄이는 스탭
        self.train_size = 1e8   # 훈련시 이미지 갯수??
        self.lr_init = 0.0002        # 최초의 lr
        self.load_size = 286
        self.save_freq = 500    # 저장 빈도
        self.continue_train = True         # 항상 연속해서 훈련.

        # 경로 모음
        self.checkpoint_dir = checkpoint_dir                # checkpoint 경로.
        self.dataset_dir = dataset_dir              # dataset 경로
        self.test_dir = test_dir                    # 테스트한 이미지를 저장하는 경로.

        # G와 D
        self.discriminator = discriminator
        self.generator = generator_resnet  # resnet을 사용한 generator

        # loss_fn
        self.original_GAN_loss = mae_criterion

        self.which_direction = which_direction

        OPTIONS = namedtuple('OPTIONS', 'batch_size image_size \
                                      gf_dim df_dim output_c_dim')
        self.options = OPTIONS._make((self.batch_size, self.fine_size,
                                      self.ngf, self.ndf, self.output_nc,))       #ngf 는 제너레이터 함수의 첫번째 conv레이어 필터수
                                      #self.phase == 'train'))

        self._build_model()         # 모델 생성.
        #writer = tf.train.SummaryWriter("/tmp/test_logs", sess.graph)
        self.saver = tf.train.Saver()
        self.pool = ImagePool(self.max_size)

    def _build_model(self):
        self.real_data = tf.placeholder(tf.float32,
                                        [None, self.image_size, self.image_size,
                                         self.input_c_dim + self.output_c_dim],     # input 이미지 채널과 output 이미지 채널 수  # 아마 둘다 3. RGB라서.
                                        name='real_A_and_B_images')

        self.real_A = self.real_data[:, :, :, :self.input_c_dim]            # self.real_data의 앞부분, 즉 real A
        self.real_B = self.real_data[:, :, :, self.input_c_dim:self.input_c_dim + self.output_c_dim] # real B
        self.fake_B = self.generator(self.real_A, self.options, False, name="generatorA2B")     # A를 가짜 B로 바꾸기.
        self.fake_A_ = self.generator(self.fake_B, self.options, False, name="generatorB2A")    # 가짜 B를 가짜 A로 바꾸기

        # 앞에 이미 정의한 거라서 reuse를 사용함.
        self.fake_A = self.generator(self.real_B, self.options, True, name="generatorB2A")      # 진짜 B를 가짜 A로 바꾸기
        self.fake_B_ = self.generator(self.fake_A, self.options, True, name="generatorA2B")     # 가짜 A를 가짜 B로 바꾸기
        self.DB_fake = self.discriminator(self.fake_B, self.options, reuse=False, name="discriminatorB")        # 32 BY 32 가 나와..
        self.DA_fake = self.discriminator(self.fake_A, self.options, reuse=False, name="discriminatorA")

        """  G & F 를 학습 시키키 위해 필요한 최종 loss  """
        self.g_loss = self.original_GAN_loss(self.DA_fake, tf.ones_like(self.DA_fake)) \
            + self.original_GAN_loss(self.DB_fake, tf.ones_like(self.DB_fake)) \
            + self.L1_lambda * abs_criterion(self.real_A, self.fake_A_) \
            + self.L1_lambda * abs_criterion(self.real_B, self.fake_B_)

        """    신규 추가 loss   
        #########################################################
        self.A_and_GA_hyunbo = self.generator(self.real_A, self.options, True, name="generatorB2A")
        self.B_and_GB_hyunbo = self.generator(self.real_B, self.options, True, name="generatorA2B")
        self.g_loss_by_hyunbo = self.L1_lambda * abs_criterion(self.real_A, self.A_and_GA_hyunbo) \
                                    + self.L1_lambda * abs_criterion(self.real_B, self.B_and_GB_hyunbo)
        #########################################################"""
        """ =============================== 여기부터는 D의 학습입니다. =========================="""
        # 대문자 D를 함수 처럼 작용하는 듯.
        self.fake_A_sample = tf.placeholder(tf.float32,
                                            [None, self.image_size, self.image_size,
                                             self.input_c_dim], name='fake_A_sample')
        self.fake_B_sample = tf.placeholder(tf.float32,
                                            [None, self.image_size, self.image_size,
                                             self.output_c_dim], name='fake_B_sample')

        # 진짜 B를 넣어서 32 by 32 를 나오게 함.
        self.DB_real = self.discriminator(self.real_B, self.options, reuse=True, name="discriminatorB")
        # 진짜 A를 넣어서 32 by 32 를 나오게 함.
        self.DA_real = self.discriminator(self.real_A, self.options, reuse=True, name="discriminatorA")
        # 가짜 B를 넣어서 32 by 32 를 나오게 함.
        self.DB_fake_sample = self.discriminator(self.fake_B_sample, self.options, reuse=True, name="discriminatorB")
        # 가짜 A를 넣어서 32 by 32 를 나오게 함.
        self.DA_fake_sample = self.discriminator(self.fake_A_sample, self.options, reuse=True, name="discriminatorA")

        """ 진짜 B와 가짜 B를 구별하는 D_loss"""
        self.db_loss_real = self.original_GAN_loss(self.DB_real, tf.ones_like(self.DB_real))
        self.db_loss_fake = self.original_GAN_loss(self.DB_fake_sample, tf.zeros_like(self.DB_fake_sample))
        self.db_loss = (self.db_loss_real + self.db_loss_fake) / 2

        """ 진짜 A와 가짜 A를 구별하는 D_loss """
        self.da_loss_real = self.original_GAN_loss(self.DA_real, tf.ones_like(self.DA_real))
        self.da_loss_fake = self.original_GAN_loss(self.DA_fake_sample, tf.zeros_like(self.DA_fake_sample))
        self.da_loss = (self.da_loss_real + self.da_loss_fake) / 2

        """ D를 학습시키기 위한 최종 loss """
        self.d_loss = self.da_loss + self.db_loss

        """============================================================================================"""

        """ test를 위해 만든 곳 """
        self.test_A = tf.placeholder(tf.float32,
                                     [None, self.image_size, self.image_size,
                                      self.input_c_dim], name='test_A')
        self.test_B = tf.placeholder(tf.float32,
                                     [None, self.image_size, self.image_size,
                                      self.output_c_dim], name='test_B')
        self.testB = self.generator(self.test_A, self.options, True, name="generatorA2B")
        self.testA = self.generator(self.test_B, self.options, True, name="generatorB2A")


        """ D를 학습시킬 때의 변수와 G를 학습시킬 때의 변수를 나눠놓음. """
        t_vars = tf.trainable_variables()
        self.d_vars = [var for var in t_vars if 'discriminator' in var.name]
        self.g_vars = [var for var in t_vars if 'generator' in var.name]
        for var in t_vars: print(var.name)

    def train(self):
        """Train cyclegan"""
        self.lr_var = tf.placeholder(tf.float32, None, name='learning_rate')
        self.d_optim = tf.train.AdamOptimizer(self.lr_var, beta1=self.beta1) \
            .minimize(self.d_loss, var_list=self.d_vars)
        self.g_optim = tf.train.AdamOptimizer(self.lr_var, beta1=self.beta1) \
            .minimize(self.g_loss, var_list=self.g_vars)

        """
        #########################################################
        self.hyunbo_optim = tf.train.AdamOptimizer(self.lr_var, beta1=self.beta1) \
            .minimize(self.g_loss_by_hyunbo, var_list=self.g_vars)
        #########################################################
        """

        init_op = tf.global_variables_initializer()     #모든 변수 초기화.
        self.sess.run(init_op)

        counter = 1
        start_time = time.time()

        if self.continue_train:
            suc_or_fal, num_of_train = self.load()          # 성공, 실패 유무 와 훈련횟수
            if suc_or_fal:
                print(" check point 가져오기 성공")
                counter = int(num_of_train)                     # 이어서 저장하기 위해서..
                print('counter: ', counter)
            else:
                print(" check point 가져오기 실패")

        for epoch in range(self.epoch):
            dataA = glob('{}/*.*'.format(self.dataset_dir + '/trainA'))
            dataB = glob('{}/*.*'.format(self.dataset_dir + '/trainB'))
            print("num of dataA : ", dataA.__len__())
            np.random.shuffle(dataA)
            np.random.shuffle(dataB)
            batch_idxs = min(min(len(dataA), len(dataB)), self.train_size) // self.batch_size
            lr = self.lr_init if epoch < self.epoch_step else self.lr_init*(self.epoch-epoch)/(self.epoch-self.epoch_step)    # lr이 작아짐. 100에폭이 지나면.

            for idx in range(0, batch_idxs):
                batch_files = list(zip(dataA[idx * self.batch_size:(idx + 1) * self.batch_size],
                                       dataB[idx * self.batch_size:(idx + 1) * self.batch_size]))
                batch_images = [load_train_data(batch_file, self.load_size, self.fine_size) for batch_file in batch_files]      # 이미지 크기 바꾸기.
                batch_images = np.array(batch_images).astype(np.float32)

                # Update G network and record fake outputs
                fake_A, fake_B, _ = self.sess.run(
                    [self.fake_A, self.fake_B, self.g_optim],
                    feed_dict={self.real_data: batch_images, self.lr_var: lr})

                #self.writer.add_summary(summary_str, counter)
                #[fake_A, fake_B] = self.pool([fake_A, fake_B])

                # Update D network
                self.sess.run( [self.d_optim],
                               feed_dict={self.real_data: batch_images,
                                    self.fake_A_sample: fake_A,
                                    self.fake_B_sample: fake_B,
                                    self.lr_var: lr})
                #self.writer.add_summary(summary_str, counter)

                counter += 1
                print(("Epoch: [%2d] [%4d/%4d] time: %4.4f" % (
                    epoch, idx, batch_idxs, time.time() - start_time)))

                # 저장.
                if np.mod(counter, self.save_freq) == 2:
                    self.save(counter)
                    print("ckpt 저장 완료")
            if epoch % 5 == 0:
                # !rm checkpoint.zip
                # !zip -r /content/checkpoint.zip ./checkpoint/
                shutil.copyfile('./checkpoint.zip', 'drive/My Drive/Ipre/checkpointTestNuevo14s1819{}BtoAoff.zip'.format(str(counter)))

    def save(self, step):

        step_str = str(step)

        self.saver.save(self.sess,
                        self.checkpoint_dir + "/" + step_str,
                        global_step=step)

        """ 여기는 ckpt 파일을 gdrive에 올리는 코드입니다."""
        """latest = tf.train.latest_checkpoint(checkpoint_dir)
        file_name = latest.split("/")
        file_name = file_name[-1]
        list = ['.data-00000-of-00001', '.index', '.meta']
        for x in list:
            drive_service = build('drive', 'v3')
            file_metadata = {
                'name': file_name + x,  # 구글에 올라가는 이름
                'mimeType': None
            }
            media = MediaFileUpload('' + latest + x,
                                    mimetype=None,
                                    resumable=True)
            created = drive_service.files().create(body=file_metadata,
                                                   media_body=media,
                                                   fields='id').execute()
            print('File ID: {}'.format(created.get('id')))
            print(x + "gdrive에 올리기 성공")"""

    def load(self):
        print(" [*] Reading checkpoint...")

        #model_dir = "%s_%s" % (self.dataset_dir, self.image_size)
        #checkpoint_dir = os.path.join(checkpoint_dir, model_dir)

        ckpt = tf.train.get_checkpoint_state(self.checkpoint_dir)
        if ckpt and ckpt.model_checkpoint_path:
            ckpt_name = os.path.basename(ckpt.model_checkpoint_path)
            self.saver.restore(self.sess, os.path.join(self.checkpoint_dir, ckpt_name))
            print(" 체크 포인트 이름!! : ", ckpt_name)
            index = ckpt_name.find("-")
            num_of_train = ckpt_name[index + 1:]
            print("NUM OF TRAIN: ", num_of_train)
            print(" 불러온 ckpt 횟수 : ", num_of_train)
            return True, num_of_train
        else:
            print("check point가 경로에 없습니다.")
            return False, 1             # 리턴값 맞춰주기 위해 씀. 아무값이나 리턴

    def test(self):
        """Test cyclegan"""
        init_op = tf.global_variables_initializer()
        self.sess.run(init_op)
        if self.which_direction == 'AtoB':
            sample_files = glob('{}/*.*'.format(self.dataset_dir + '/testA'))
            print("dataset 가져오기 성공.")
        elif self.which_direction == 'BtoA':
            sample_files = glob('{}/*.*'.format(self.dataset_dir + '/testB'))
            print("dataset 가져오기 성공.")
        else:
            raise Exception('AtoB BtoA 둘중 하나는 선택하세요.')

        if self.load():
            print(" check point 가져오기 성공")
        else:
            print(" check point 가져오기 실패")

        if self.which_direction == 'AtoB':
            out_var, in_var = (self.testB, self.test_A)
        else:
            out_var, in_var = (self.testA, self.test_B)

        for sample_file in sample_files:
            print('Processing image: ' + sample_file)
            sample_image = [load_test_data(sample_file, self.fine_size)]
            sample_image = np.array(sample_image).astype(np.float32)
            image_path = os.path.join(self.test_dir,
                                      '{0}_{1}'.format(self.which_direction, os.path.basename(sample_file)))
            fake_img = self.sess.run(out_var, feed_dict={in_var: sample_image})
            print("start saving")
            save_images(fake_img, [1, 1], image_path)

# %%
def main():
    checkpoint_dir = './checkpoint/face_256'             # 체크포인트 경로
    test_dir = './genImages'                          # 테스트 이미지가 저장되는 경로
    dataset_dir = './'                         # 데이터셋 위치    trainA trainB testA testB
    phase = "test"  # or test
    which_direction = "BtoA"        # or BtoA .  테스트시 변환 방향
    # 이미지 저장은 test 경로를 따로 만들어서 함.

    if not os.path.exists(checkpoint_dir):
        os.makedirs(checkpoint_dir)
    if not os.path.exists(test_dir):
        os.makedirs(test_dir)

    tfconfig = tf.ConfigProto(allow_soft_placement=True)        # gpu를 사용하겠습니다.
    tfconfig.gpu_options.allow_growth = True

    with tf.Session(config=tfconfig) as sess:
        model = cyclegan(sess, checkpoint_dir = checkpoint_dir, test_dir = test_dir,\
                         dataset_dir= dataset_dir, which_direction= which_direction)
        if phase == 'train':
            print(" 훈련 시작")
            model.train()
        elif phase == "test":
            print(" 테스트 시작")
            model.test()
        else:
            print(" train??? test???? 둘중하나는 고르세요.")

# %%
# !unzip trainA.zip
# !unzip trainB.zip
# !unzip testB.zip
# !unzip testA.zip

# %%
main()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From <ipython-input-3-748d4191ec67>:113: calling RandomNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# generatorA2B/g_e1_c/Conv/weights:0
# generatorA2B/g_e1_bn/scale:0
# generatorA2B/g_e1_bn/offset:0
# generatorA2B/g_e2_c/Conv/weights:0
# generatorA2B/g_e2_bn/scale:0
# generatorA2B/g_e2_bn/offset:0
# generatorA2B/g_e3_c/Conv/weights:0
# generatorA2B/g_e3_bn/scale:0
# generatorA2B/g_e3_bn/offset:0
# generatorA2B/g_r1_c1/Conv/weights:0
# generatorA2B/g_r1_bn1/scale:0
# generatorA2B/g_r1_bn1/offset:0
# generatorA2B/g_r1_c2/Conv/weights:0
# generatorA2B/g_r1_bn2/scale:0
# generatorA2B/g_r1_bn2/offset:0
# generatorA2B/g_r2_c1/Conv/weights:0
# generatorA2B/g_r2_bn1/scale:0
# generatorA2B/g_r2_bn1/offset:0
# generatorA2B/g_r2_c2/Conv/weights:0
# generatorA2B/g_r2_bn2/scale:0
# generatorA2B/g_r2_bn2/offset:0
# generatorA2B/g_r3_c1/Conv/weights:0
# generatorA2B/g_r3_bn1/scale:0
# generatorA2B/g_r3_bn1/offset:0
# generatorA2B/g_r3_c2/Conv/weights:0
# generatorA2B/g_r3_bn2/scale:0
# generatorA2B/g_r3_bn2/offset:0
# generatorA2B/g_r4_c1/Conv/weights:0
# generatorA2B/g_r4_bn1/scale:0
# generatorA2B/g_r4_bn1/offset:0
# generatorA2B/g_r4_c2/Conv/weights:0
# generatorA2B/g_r4_bn2/scale:0
# generatorA2B/g_r4_bn2/offset:0
# generatorA2B/g_r5_c1/Conv/weights:0
# generatorA2B/g_r5_bn1/scale:0
# generatorA2B/g_r5_bn1/offset:0
# generatorA2B/g_r5_c2/Conv/weights:0
# generatorA2B/g_r5_bn2/scale:0
# generatorA2B/g_r5_bn2/offset:0
# generatorA2B/g_r6_c1/Conv/weights:0
# generatorA2B/g_r6_bn1/scale:0
# generatorA2B/g_r6_bn1/offset:0
# generatorA2B/g_r6_c2/Conv/weights:0
# generatorA2B/g_r6_bn2/scale:0
# generatorA2B/g_r6_bn2/offset:0
# generatorA2B/g_r7_c1/Conv/weights:0
# generatorA2B/g_r7_bn1/scale:0
# generatorA2B/g_r7_bn1/offset:0
# generatorA2B/g_r7_c2/Conv/weights:0
# generatorA2B/g_r7_bn2/scale:0
# generatorA2B/g_r7_bn2/offset:0
# generatorA2B/g_r8_c1/Conv/weights:0
# generatorA2B/g_r8_bn1/scale:0
# generatorA2B/g_r8_bn1/offset:0
# generatorA2B/g_r8_c2/Conv/weights:0
# generatorA2B/g_r8_bn2/scale:0
# generatorA2B/g_r8_bn2/offset:0
# generatorA2B/g_r9_c1/Conv/weights:0
# generatorA2B/g_r9_bn1/scale:0
# generatorA2B/g_r9_bn1/offset:0
# generatorA2B/g_r9_c2/Conv/weights:0
# generatorA2B/g_r9_bn2/scale:0
# generatorA2B/g_r9_bn2/offset:0
# generatorA2B/g_d1_dc/Conv2d_transpose/weights:0
# generatorA2B/g_d1_bn/scale:0
# generatorA2B/g_d1_bn/offset:0
# generatorA2B/g_d2_dc/Conv2d_transpose/weights:0
# generatorA2B/g_d2_bn/scale:0
# generatorA2B/g_d2_bn/offset:0
# generatorA2B/g_pred_c/Conv/weights:0
# generatorB2A/g_e1_c/Conv/weights:0
# generatorB2A/g_e1_bn/scale:0
# generatorB2A/g_e1_bn/offset:0
# generatorB2A/g_e2_c/Conv/weights:0
# generatorB2A/g_e2_bn/scale:0
# generatorB2A/g_e2_bn/offset:0
# generatorB2A/g_e3_c/Conv/weights:0
# generatorB2A/g_e3_bn/scale:0
# generatorB2A/g_e3_bn/offset:0
# generatorB2A/g_r1_c1/Conv/weights:0
# generatorB2A/g_r1_bn1/scale:0
# generatorB2A/g_r1_bn1/offset:0
# generatorB2A/g_r1_c2/Conv/weights:0
# generatorB2A/g_r1_bn2/scale:0
# generatorB2A/g_r1_bn2/offset:0
# generatorB2A/g_r2_c1/Conv/weights:0
# generatorB2A/g_r2_bn1/scale:0
# generatorB2A/g_r2_bn1/offset:0
# generatorB2A/g_r2_c2/Conv/weights:0
# generatorB2A/g_r2_bn2/scale:0
# generatorB2A/g_r2_bn2/offset:0
# generatorB2A/g_r3_c1/Conv/weights:0
# generatorB2A/g_r3_bn1/scale:0
# generatorB2A/g_r3_bn1/offset:0
# generatorB2A/g_r3_c2/Conv/weights:0
# generatorB2A/g_r3_bn2/scale:0
# generatorB2A/g_r3_bn2/offset:0
# generatorB2A/g_r4_c1/Conv/weights:0
# generatorB2A/g_r4_bn1/scale:0
# generatorB2A/g_r4_bn1/offset:0
# generatorB2A/g_r4_c2/Conv/weights:0
# generatorB2A/g_r4_bn2/scale:0
# generatorB2A/g_r4_bn2/offset:0
# generatorB2A/g_r5_c1/Conv/weights:0
# generatorB2A/g_r5_bn1/scale:0
# generatorB2A/g_r5_bn1/offset:0
# generatorB2A/g_r5_c2/Conv/weights:0
# generatorB2A/g_r5_bn2/scale:0
# generatorB2A/g_r5_bn2/offset:0
# generatorB2A/g_r6_c1/Conv/weights:0
# generatorB2A/g_r6_bn1/scale:0
# generatorB2A/g_r6_bn1/offset:0
# generatorB2A/g_r6_c2/Conv/weights:0
# generatorB2A/g_r6_bn2/scale:0
# generatorB2A/g_r6_bn2/offset:0
# generatorB2A/g_r7_c1/Conv/weights:0
# generatorB2A/g_r7_bn1/scale:0
# generatorB2A/g_r7_bn1/offset:0
# generatorB2A/g_r7_c2/Conv/weights:0
# generatorB2A/g_r7_bn2/scale:0
# generatorB2A/g_r7_bn2/offset:0
# generatorB2A/g_r8_c1/Conv/weights:0
# generatorB2A/g_r8_bn1/scale:0
# generatorB2A/g_r8_bn1/offset:0
# generatorB2A/g_r8_c2/Conv/weights:0
# generatorB2A/g_r8_bn2/scale:0
# generatorB2A/g_r8_bn2/offset:0
# generatorB2A/g_r9_c1/Conv/weights:0
# generatorB2A/g_r9_bn1/scale:0
# generatorB2A/g_r9_bn1/offset:0
# generatorB2A/g_r9_c2/Conv/weights:0
# generatorB2A/g_r9_bn2/scale:0
# generatorB2A/g_r9_bn2/offset:0
# generatorB2A/g_d1_dc/Conv2d_transpose/weights:0
# generatorB2A/g_d1_bn/scale:0
# generatorB2A/g_d1_bn/offset:0
# generatorB2A/g_d2_dc/Conv2d_transpose/weights:0
# generatorB2A/g_d2_bn/scale:0
# generatorB2A/g_d2_bn/offset:0
# generatorB2A/g_pred_c/Conv/weights:0
# discriminatorB/d_h0_conv/Conv/weights:0
# discriminatorB/d_h1_conv/Conv/weights:0
# discriminatorB/d_bn1/scale:0
# discriminatorB/d_bn1/offset:0
# discriminatorB/d_h2_conv/Conv/weights:0
# discriminatorB/d_bn2/scale:0
# discriminatorB/d_bn2/offset:0
# discriminatorB/d_h3_conv/Conv/weights:0
# discriminatorB/d_bn3/scale:0
# discriminatorB/d_bn3/offset:0
# discriminatorB/d_h3_pred/Conv/weights:0
# discriminatorA/d_h0_conv/Conv/weights:0
# discriminatorA/d_h1_conv/Conv/weights:0
# discriminatorA/d_bn1/scale:0
# discriminatorA/d_bn1/offset:0
# discriminatorA/d_h2_conv/Conv/weights:0
# discriminatorA/d_bn2/scale:0
# discriminatorA/d_bn2/offset:0
# discriminatorA/d_h3_conv/Conv/weights:0
# discriminatorA/d_bn3/scale:0
# discriminatorA/d_bn3/offset:0
# discriminatorA/d_h3_pred/Conv/weights:0
#  테스트 시작
# dataset 가져오기 성공.
#  [*] Reading checkpoint...
# INFO:tensorflow:Restoring parameters from ./checkpoint/face_256/32002-32002
#  체크 포인트 이름!! :  32002-32002
# NUM OF TRAIN:  32002
#  불러온 ckpt 횟수 :  32002
#  check point 가져오기 성공
# Processing image: .//testB/026260B.jpg
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:189: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:148: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# start saving
# Processing image: .//testB/026350B.jpg
# start saving
# Processing image: .//testB/019228B.jpg
# start saving
# Processing image: .//testB/003543B.jpg
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:205: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# start saving
# Processing image: .//testB/031665B.jpg
# start saving
# Processing image: .//testB/005578B.jpg
# start saving
# Processing image: .//testB/023245B.jpg
# start saving
# Processing image: .//testB/022322B.jpg
# start saving
# Processing image: .//testB/019838B.jpg
# start saving
# Processing image: .//testB/025470B.jpg
# start saving
# Processing image: .//testB/040267B.jpg
# start saving
# Processing image: .//testB/022900B.jpg
# start saving
# Processing image: .//testB/038118B.jpg
# start saving
# Processing image: .//testB/039480B.jpg
# start saving
# Processing image: .//testB/036789B.jpg
# start saving
# Processing image: .//testB/019322B.jpg
# start saving
# Processing image: .//testB/037194B.jpg
# start saving
# Processing image: .//testB/001037B.jpg
# start saving
# Processing image: .//testB/027439B.jpg
# start saving
# Processing image: .//testB/007647B.jpg
# start saving
# Processing image: .//testB/035398B.jpg
# start saving
# Processing image: .//testB/015432B.jpg
# start saving
# Processing image: .//testB/032657B.jpg
# start saving
# Processing image: .//testB/013021B.jpg
# start saving
# Processing image: .//testB/035875B.jpg
# start saving
# Processing image: .//testB/016288B.jpg
# start saving
# Processing image: .//testB/000654B.jpg
# start saving
# Processing image: .//testB/029180B.jpg
# start saving
# Processing image: .//testB/018971B.jpg
# start saving
# Processing image: .//testB/019508B.jpg
# start saving
# Processing image: .//testB/037329B.jpg
# start saving
# Processing image: .//testB/039305B.jpg
# start saving
# Processing image: .//testB/018089B.jpg
# start saving
# Processing image: .//testB/022737B.jpg
# start saving
# Processing image: .//testB/024701B.jpg
# start saving
# Processing image: .//testB/040071B.jpg
# start saving
# Processing image: .//testB/019758B.jpg
# start saving
# Processing image: .//testB/012446B.jpg
# start saving
# Processing image: .//testB/039036B.jpg
# start saving
# Processing image: .//testB/030611B.jpg
# start saving
# Processing image: .//testB/025274B.jpg
# start saving
# Processing image: .//testB/037719B.jpg
# start saving
# Processing image: .//testB/029421B.jpg
# start saving
# Processing image: .//testB/035654B.jpg
# start saving
# Processing image: .//testB/002653B.jpg
# start saving
# Processing image: .//testB/035092B.jpg
# start saving
# Processing image: .//testB/032076B.jpg
# start saving
# Processing image: .//testB/037372B.jpg
# start saving
# Processing image: .//testB/018887B.jpg
# start saving
# Processing image: .//testB/038820B.jpg
# start saving
# Processing image: .//testB/035658B.jpg
# start saving
# Processing image: .//testB/026925B.jpg
# start saving
# Processing image: .//testB/000650B.jpg
# start saving
# Processing image: .//testB/035862B.jpg
# start saving
# Processing image: .//testB/032608B.jpg
# start saving
# Processing image: .//testB/011847B.jpg
# start saving
# Processing image: .//testB/006827B.jpg
# start saving
# Processing image: .//testB/011882B.jpg
# start saving
# Processing image: .//testB/028729B.jpg
# start saving
# Processing image: .//testB/026306B.jpg
# start saving
# Processing image: .//testB/018031B.jpg
# start saving
# Processing image: .//testB/019066B.jpg
# start saving
# Processing image: .//testB/006760B.jpg
# start saving
# Processing image: .//testB/036306B.jpg
# start saving
# Processing image: .//testB/022059B.jpg
# start saving
# Processing image: .//testB/018209B.jpg
# start saving
# Processing image: .//testB/018402B.jpg
# start saving
# Processing image: .//testB/019600B.jpg
# start saving
# Processing image: .//testB/018968B.jpg
# start saving
# Processing image: .//testB/026773B.jpg
# start saving
# Processing image: .//testB/023233B.jpg
# start saving
# Processing image: .//testB/007146B.jpg
# start saving
# Processing image: .//testB/040011B.jpg
# start saving
# Processing image: .//testB/023241B.jpg
# start saving
# Processing image: .//testB/027009B.jpg
# start saving
# Processing image: .//testB/018092B.jpg
# start saving
# Processing image: .//testB/029723B.jpg
# start saving
# Processing image: .//testB/001111B.jpg
# start saving
# Processing image: .//testB/024659B.jpg
# start saving
# Processing image: .//testB/021777B.jpg
# start saving
# Processing image: .//testB/025908B.jpg
# start saving
# Processing image: .//testB/024858B.jpg
# start saving
# Processing image: .//testB/025163B.jpg
# start saving
# Processing image: .//testB/026735B.jpg
# start saving
# Processing image: .//testB/039641B.jpg
# start saving
# Processing image: .//testB/018205B.jpg
# start saving
# Processing image: .//testB/032304B.jpg
# start saving
# Processing image: .//testB/006714B.jpg
# start saving
# Processing image: .//testB/001613B.jpg
# start saving
# Processing image: .//testB/033356B.jpg
# start saving
# Processing image: .//testB/003915B.jpg
# start saving
# Processing image: .//testB/007076B.jpg
# start saving
# Processing image: .//testB/036937B.jpg
# start saving
# Processing image: .//testB/024772B.jpg
# start saving
# Processing image: .//testB/004962B.jpg
# start saving
# Processing image: .//testB/031618B.jpg
# start saving
# Processing image: .//testB/025855B.jpg
# start saving
# Processing image: .//testB/027018B.jpg
# start saving
# Processing image: .//testB/022882B.jpg
# start saving
# Processing image: .//testB/016063B.jpg
# start saving
# Processing image: .//testB/022976B.jpg
# start saving
# Processing image: .//testB/030090B.jpg
# start saving
# Processing image: .//testB/026555B.jpg
# start saving
# Processing image: .//testB/013936B.jpg
# start saving
# Processing image: .//testB/027445B.jpg
# start saving
# Processing image: .//testB/022995B.jpg
# start saving
# Processing image: .//testB/020360B.jpg
# start saving
# Processing image: .//testB/033267B.jpg
# start saving
# Processing image: .//testB/019191B.jpg
# start saving
# Processing image: .//testB/020079B.jpg
# start saving
# Processing image: .//testB/036941B.jpg
# start saving
# Processing image: .//testB/019650B.jpg
# start saving
# Processing image: .//testB/005871B.jpg
# start saving
# Processing image: .//testB/023188B.jpg
# start saving
# Processing image: .//testB/018563B.jpg
# start saving
# Processing image: .//testB/022278B.jpg
# start saving
# Processing image: .//testB/032447B.jpg
# start saving
# Processing image: .//testB/038955B.jpg
# start saving
# Processing image: .//testB/001610B.jpg
# start saving
# Processing image: .//testB/025398B.jpg
# start saving
# Processing image: .//testB/026367B.jpg
# start saving
# Processing image: .//testB/025207B.jpg
# start saving
# Processing image: .//testB/039265B.jpg
# start saving
# Processing image: .//testB/006529B.jpg
# start saving
# Processing image: .//testB/029666B.jpg
# start saving
# Processing image: .//testB/033631B.jpg
# start saving
# Processing image: .//testB/025395B.jpg
# start saving
# Processing image: .//testB/019174B.jpg
# start saving
# Processing image: .//testB/029298B.jpg
# start saving
# Processing image: .//testB/007075B.jpg
# start saving
# Processing image: .//testB/038006B.jpg
# start saving
# Processing image: .//testB/017945B.jpg
# start saving
# Processing image: .//testB/031052B.jpg
# start saving
# Processing image: .//testB/024166B.jpg
# start saving
# Processing image: .//testB/030010B.jpg
# start saving
# Processing image: .//testB/017742B.jpg
# start saving
# Processing image: .//testB/028734B.jpg
# start saving
# Processing image: .//testB/011037B.jpg
# start saving
# Processing image: .//testB/020085B.jpg
# start saving
# Processing image: .//testB/025784B.jpg
# start saving
# Processing image: .//testB/033613B.jpg
# start saving
# Processing image: .//testB/040176B.jpg
# start saving
# Processing image: .//testB/024767B.jpg
# start saving
# Processing image: .//testB/025226B.jpg
# start saving
# Processing image: .//testB/004394B.jpg
# start saving
# Processing image: .//testB/028564B.jpg
# start saving
# Processing image: .//testB/021540B.jpg
# start saving
# Processing image: .//testB/039876B.jpg
# start saving
# Processing image: .//testB/027034B.jpg
# start saving
# Processing image: .//testB/029430B.jpg
# start saving
# Processing image: .//testB/026929B.jpg
# start saving
# Processing image: .//testB/039468B.jpg
# start saving
# Processing image: .//testB/005942B.jpg
# start saving
# Processing image: .//testB/024464B.jpg
# start saving
# Processing image: .//testB/025926B.jpg
# start saving
# Processing image: .//testB/021986B.jpg
# start saving
# Processing image: .//testB/025904B.jpg
# start saving
# Processing image: .//testB/003831B.jpg
# start saving
# Processing image: .//testB/034692B.jpg
# start saving
# Processing image: .//testB/022257B.jpg
# start saving
# Processing image: .//testB/039021B.jpg
# start saving
# Processing image: .//testB/037217B.jpg
# start saving
# Processing image: .//testB/024940B.jpg
# start saving
# Processing image: .//testB/019522B.jpg
# start saving
# Processing image: .//testB/030873B.jpg
# start saving
# Processing image: .//testB/001381B.jpg
# start saving
# Processing image: .//testB/035010B.jpg
# start saving
# Processing image: .//testB/024651B.jpg
# start saving
# Processing image: .//testB/025090B.jpg
# start saving
# Processing image: .//testB/039908B.jpg
# start saving
# Processing image: .//testB/009951B.jpg
# start saving
# Processing image: .//testB/025081B.jpg
# start saving
# Processing image: .//testB/028077B.jpg
# start saving
# Processing image: .//testB/039976B.jpg
# start saving
# Processing image: .//testB/022225B.jpg
# start saving
# Processing image: .//testB/024465B.jpg
# start saving
# Processing image: .//testB/039181B.jpg
# start saving
# Processing image: .//testB/038294B.jpg
# start saving
# Processing image: .//testB/019445B.jpg
# start saving
# Processing image: .//testB/038794B.jpg
# start saving
# Processing image: .//testB/025546B.jpg
# start saving
# Processing image: .//testB/029702B.jpg
# start saving
# Processing image: .//testB/018608B.jpg
# start saving
# Processing image: .//testB/038589B.jpg
# start saving
# Processing image: .//testB/022237B.jpg
# start saving
# Processing image: .//testB/031915B.jpg
# start saving
# Processing image: .//testB/025559B.jpg
# start saving
# Processing image: .//testB/040536B.jpg
# start saving
# Processing image: .//testB/018767B.jpg
# start saving
# Processing image: .//testB/025063B.jpg
# start saving
# Processing image: .//testB/033244B.jpg
# start saving
# Processing image: .//testB/032868B.jpg
# start saving
# Processing image: .//testB/022609B.jpg
# start saving
# Processing image: .//testB/032555B.jpg
# start saving
# Processing image: .//testB/018271B.jpg
# start saving
# Processing image: .//testB/024165B.jpg
# start saving
# Processing image: .//testB/038492B.jpg
# start saving
# Processing image: .//testB/039624B.jpg
# start saving
# Processing image: .//testB/034305B.jpg
# start saving
# Processing image: .//testB/002311B.jpg
# start saving
# Processing image: .//testB/020126B.jpg
# start saving
# Processing image: .//testB/012497B.jpg
# start saving
# Processing image: .//testB/029254B.jpg
# start saving
# Processing image: .//testB/012201B.jpg
# start saving
# Processing image: .//testB/023454B.jpg
# start saving
# Processing image: .//testB/011138B.jpg
# start saving
# Processing image: .//testB/026794B.jpg
# start saving
# Processing image: .//testB/040511B.jpg
# start saving
# Processing image: .//testB/019693B.jpg
# start saving
# Processing image: .//testB/035704B.jpg
# start saving
# Processing image: .//testB/037080B.jpg
# start saving
# Processing image: .//testB/017996B.jpg
# start saving
# Processing image: .//testB/024230B.jpg
# start saving
# Processing image: .//testB/038206B.jpg
# start saving
# Processing image: .//testB/022785B.jpg
# start saving
# Processing image: .//testB/026619B.jpg
# start saving
# Processing image: .//testB/039030B.jpg
# start saving
# Processing image: .//testB/018224B.jpg
# start saving
# Processing image: .//testB/024919B.jpg
# start saving
# Processing image: .//testB/038376B.jpg
# start saving
# Processing image: .//testB/033483B.jpg
# start saving
# Processing image: .//testB/018703B.jpg
# start saving
# Processing image: .//testB/040519B.jpg
# start saving
# Processing image: .//testB/024681B.jpg
# start saving
# Processing image: .//testB/026434B.jpg
# start saving
# Processing image: .//testB/029801B.jpg
# start saving
# Processing image: .//testB/033366B.jpg
# start saving
# Processing image: .//testB/038484B.jpg
# start saving
# Processing image: .//testB/014755B.jpg
# start saving
# Processing image: .//testB/039462B.jpg
# start saving
# Processing image: .//testB/023173B.jpg
# start saving
# Processing image: .//testB/026691B.jpg
# start saving
# Processing image: .//testB/038740B.jpg
# start saving
# Processing image: .//testB/039303B.jpg
# start saving
# Processing image: .//testB/019291B.jpg
# start saving
# Processing image: .//testB/022624B.jpg
# start saving
# Processing image: .//testB/000156B.jpg
# start saving
# Processing image: .//testB/023010B.jpg
# start saving
# Processing image: .//testB/023246B.jpg
# start saving
# Processing image: .//testB/024507B.jpg
# start saving
# Processing image: .//testB/005035B.jpg
# start saving
# Processing image: .//testB/019379B.jpg
# start saving
# Processing image: .//testB/034010B.jpg
# start saving
# Processing image: .//testB/033371B.jpg
# start saving
# Processing image: .//testB/002826B.jpg
# start saving
# Processing image: .//testB/040449B.jpg
# start saving
# Processing image: .//testB/033937B.jpg
# start saving
# Processing image: .//testB/033114B.jpg
# start saving
# Processing image: .//testB/026338B.jpg
# start saving
# Processing image: .//testB/036039B.jpg
# start saving
# Processing image: .//testB/034004B.jpg
# start saving
# Processing image: .//testB/039426B.jpg
# start saving
# Processing image: .//testB/004853B.jpg
# start saving
# Processing image: .//testB/027048B.jpg
# start saving
# Processing image: .//testB/037246B.jpg
# start saving
# Processing image: .//testB/029264B.jpg
# start saving
# Processing image: .//testB/031622B.jpg
# start saving
# Processing image: .//testB/034664B.jpg
# start saving
# Processing image: .//testB/022133B.jpg
# start saving
# Processing image: .//testB/039502B.jpg
# start saving
# Processing image: .//testB/024869B.jpg
# start saving
# Processing image: .//testB/025924B.jpg
# start saving
# Processing image: .//testB/024229B.jpg
# start saving
# Processing image: .//testB/030110B.jpg
# start saving
# Processing image: .//testB/038887B.jpg
# start saving
# Processing image: .//testB/025124B.jpg
# start saving
# Processing image: .//testB/029060B.jpg
# start saving
# Processing image: .//testB/021772B.jpg
# start saving
# Processing image: .//testB/029375B.jpg
# start saving
# Processing image: .//testB/037442B.jpg
# start saving
# Processing image: .//testB/029599B.jpg
# start saving
# Processing image: .//testB/018849B.jpg
# start saving
# Processing image: .//testB/031193B.jpg
# start saving
# Processing image: .//testB/027786B.jpg
# start saving
# Processing image: .//testB/029444B.jpg
# start saving
# Processing image: .//testB/035612B.jpg
# start saving
# Processing image: .//testB/019367B.jpg
# start saving
# Processing image: .//testB/023235B.jpg
# start saving
# Processing image: .//testB/025121B.jpg
# start saving
# Processing image: .//testB/038435B.jpg
# start saving
# Processing image: .//testB/027049B.jpg
# start saving
# Processing image: .//testB/026652B.jpg
# start saving
# Processing image: .//testB/000206B.jpg
# start saving
# Processing image: .//testB/002850B.jpg
# start saving
# Processing image: .//testB/029961B.jpg
# start saving
# Processing image: .//testB/001035B.jpg
# start saving
# Processing image: .//testB/038738B.jpg
# start saving
# Processing image: .//testB/010536B.jpg
# start saving
# Processing image: .//testB/023219B.jpg
# start saving
# Processing image: .//testB/001103B.jpg
# start saving
# Processing image: .//testB/036763B.jpg
# start saving
# Processing image: .//testB/001489B.jpg
# start saving
# Processing image: .//testB/019897B.jpg
# start saving
# Processing image: .//testB/026263B.jpg
# start saving
# Processing image: .//testB/023070B.jpg
# start saving
# Processing image: .//testB/036902B.jpg
# start saving
# Processing image: .//testB/022622B.jpg
# start saving
# Processing image: .//testB/025386B.jpg
# start saving
# Processing image: .//testB/021870B.jpg
# start saving
# Processing image: .//testB/032214B.jpg
# start saving
# Processing image: .//testB/025881B.jpg
# start saving
# Processing image: .//testB/003717B.jpg
# start saving
# Processing image: .//testB/014050B.jpg
# start saving
# Processing image: .//testB/020410B.jpg
# start saving
# Processing image: .//testB/023150B.jpg
# start saving
# Processing image: .//testB/011063B.jpg
# start saving
# Processing image: .//testB/029089B.jpg
# start saving
# Processing image: .//testB/006741B.jpg
# start saving
# Processing image: .//testB/020077B.jpg
# start saving
# Processing image: .//testB/025142B.jpg
# start saving
# Processing image: .//testB/016038B.jpg
# start saving
# Processing image: .//testB/029812B.jpg
# start saving
# Processing image: .//testB/021314B.jpg
# start saving
# Processing image: .//testB/024615B.jpg
# start saving
# Processing image: .//testB/034605B.jpg
# start saving
# Processing image: .//testB/019237B.jpg
# start saving
# Processing image: .//testB/024567B.jpg
# start saving
# Processing image: .//testB/033868B.jpg
# start saving
# Processing image: .//testB/024810B.jpg
# start saving
# Processing image: .//testB/026714B.jpg
# start saving
# Processing image: .//testB/028660B.jpg
# start saving
# Processing image: .//testB/011215B.jpg
# start saving
# Processing image: .//testB/020207B.jpg
# start saving
# Processing image: .//testB/018243B.jpg
# start saving
# Processing image: .//testB/022405B.jpg
# start saving
# Processing image: .//testB/034421B.jpg
# start saving
# Processing image: .//testB/033406B.jpg
# start saving
# Processing image: .//testB/018752B.jpg
# start saving
# Processing image: .//testB/024531B.jpg
# start saving
# Processing image: .//testB/003944B.jpg
# start saving
# Processing image: .//testB/018195B.jpg
# start saving
# Processing image: .//testB/010306B.jpg
# start saving
# Processing image: .//testB/026385B.jpg
# start saving
# Processing image: .//testB/026748B.jpg
# start saving
# Processing image: .//testB/020782B.jpg
# start saving
# Processing image: .//testB/024444B.jpg
# start saving
# Processing image: .//testB/026828B.jpg
# start saving
# Processing image: .//testB/038445B.jpg
# start saving
# Processing image: .//testB/034488B.jpg
# start saving
# Processing image: .//testB/003426B.jpg
# start saving
# Processing image: .//testB/019783B.jpg
# start saving
# Processing image: .//testB/025188B.jpg
# start saving
# Processing image: .//testB/022314B.jpg
# start saving
# Processing image: .//testB/033216B.jpg
# start saving
# Processing image: .//testB/000284B.jpg
# start saving
# Processing image: .//testB/037100B.jpg
# start saving
# Processing image: .//testB/035557B.jpg
# start saving
# Processing image: .//testB/019881B.jpg
# start saving
# Processing image: .//testB/017993B.jpg
# start saving
# Processing image: .//testB/039207B.jpg
# start saving
# Processing image: .//testB/025880B.jpg
# start saving
# Processing image: .//testB/032265B.jpg
# start saving
# Processing image: .//testB/025019B.jpg
# start saving
# Processing image: .//testB/032500B.jpg
# start saving
# Processing image: .//testB/025384B.jpg
# start saving
# Processing image: .//testB/027078B.jpg
# start saving
# Processing image: .//testB/033566B.jpg
# start saving
# Processing image: .//testB/022939B.jpg
# start saving
# Processing image: .//testB/033436B.jpg
# start saving
# Processing image: .//testB/015165B.jpg
# start saving
# Processing image: .//testB/026535B.jpg
# start saving
# Processing image: .//testB/012546B.jpg
# start saving
# Processing image: .//testB/031345B.jpg
# start saving
# Processing image: .//testB/005714B.jpg
# start saving
# Processing image: .//testB/032179B.jpg
# start saving
# Processing image: .//testB/034528B.jpg
# start saving
# Processing image: .//testB/031821B.jpg
# start saving
# Processing image: .//testB/038379B.jpg
# start saving
# Processing image: .//testB/019411B.jpg
# start saving
# Processing image: .//testB/002376B.jpg
# start saving
# Processing image: .//testB/034400B.jpg
# start saving
# Processing image: .//testB/038727B.jpg
# start saving
# Processing image: .//testB/036634B.jpg
# start saving
# Processing image: .//testB/038421B.jpg
# start saving
# Processing image: .//testB/038656B.jpg
# start saving
# Processing image: .//testB/024827B.jpg
# start saving
# Processing image: .//testB/029385B.jpg
# start saving
# Processing image: .//testB/029508B.jpg
# start saving
# Processing image: .//testB/007083B.jpg
# start saving
# Processing image: .//testB/009580B.jpg
# start saving
# Processing image: .//testB/032759B.jpg
# start saving
# Processing image: .//testB/039174B.jpg
# start saving
# Processing image: .//testB/017548B.jpg
# start saving
# Processing image: .//testB/033600B.jpg
# start saving
# Processing image: .//testB/039726B.jpg
# start saving
# Processing image: .//testB/026397B.jpg
# start saving
# Processing image: .//testB/036066B.jpg
# start saving
# Processing image: .//testB/026095B.jpg
# start saving
# Processing image: .//testB/015015B.jpg
# start saving
# Processing image: .//testB/038568B.jpg
# start saving
# Processing image: .//testB/024548B.jpg
# start saving
# Processing image: .//testB/033624B.jpg
# start saving
# Processing image: .//testB/021775B.jpg
# start saving
# Processing image: .//testB/026894B.jpg
# start saving
# Processing image: .//testB/017863B.jpg
# start saving
# Processing image: .//testB/008682B.jpg
# start saving
# Processing image: .//testB/029619B.jpg
# start saving
# Processing image: .//testB/003726B.jpg
# start saving
# Processing image: .//testB/008080B.jpg
# start saving
# Processing image: .//testB/004805B.jpg
# start saving
# Processing image: .//testB/025600B.jpg
# start saving
# Processing image: .//testB/034695B.jpg
# start saving
# Processing image: .//testB/039511B.jpg
# start saving
# Processing image: .//testB/024471B.jpg
# start saving
# Processing image: .//testB/034381B.jpg
# start saving
# Processing image: .//testB/029937B.jpg
# start saving
# Processing image: .//testB/009541B.jpg
# start saving
# Processing image: .//testB/023239B.jpg
# start saving
# Processing image: .//testB/029389B.jpg
# start saving
# Processing image: .//testB/007099B.jpg
# start saving
# Processing image: .//testB/023410B.jpg
# start saving
# Processing image: .//testB/037888B.jpg
# start saving
# Processing image: .//testB/038500B.jpg
# start saving
# Processing image: .//testB/034159B.jpg
# start saving
# Processing image: .//testB/005316B.jpg
# start saving
# Processing image: .//testB/004587B.jpg
# start saving
# Processing image: .//testB/025108B.jpg
# start saving
# Processing image: .//testB/037653B.jpg
# start saving
# Processing image: .//testB/038713B.jpg
# start saving
# Processing image: .//testB/014149B.jpg
# start saving
# Processing image: .//testB/018872B.jpg
# start saving
# Processing image: .//testB/026833B.jpg
# start saving
# Processing image: .//testB/040447B.jpg
# start saving
# Processing image: .//testB/027029B.jpg
# start saving
# Processing image: .//testB/005732B.jpg
# start saving
# Processing image: .//testB/015532B.jpg
# start saving
# Processing image: .//testB/022265B.jpg
# start saving
# Processing image: .//testB/040428B.jpg
# start saving
# Processing image: .//testB/023090B.jpg
# start saving
# Processing image: .//testB/021561B.jpg
# start saving
# Processing image: .//testB/024746B.jpg
# start saving
# Processing image: .//testB/014783B.jpg
# start saving
# Processing image: .//testB/025006B.jpg
# start saving
# Processing image: .//testB/032008B.jpg
# start saving
# Processing image: .//testB/017830B.jpg
# start saving
# Processing image: .//testB/021656B.jpg
# start saving
# Processing image: .//testB/026801B.jpg
# start saving
# Processing image: .//testB/028578B.jpg
# start saving
# Processing image: .//testB/017786B.jpg
# start saving
# Processing image: .//testB/010495B.jpg
# start saving
# Processing image: .//testB/035602B.jpg
# start saving
# Processing image: .//testB/002449B.jpg
# start saving
# Processing image: .//testB/025861B.jpg
# start saving
# Processing image: .//testB/022849B.jpg
# start saving
# Processing image: .//testB/008569B.jpg
# start saving
# Processing image: .//testB/023234B.jpg
# start saving
# Processing image: .//testB/037788B.jpg
# start saving
# Processing image: .//testB/022637B.jpg
# start saving
# Processing image: .//testB/039974B.jpg
# start saving
# Processing image: .//testB/019836B.jpg
# start saving
# Processing image: .//testB/023043B.jpg
# start saving
# Processing image: .//testB/038024B.jpg
# start saving
# Processing image: .//testB/026007B.jpg
# start saving
# Processing image: .//testB/038405B.jpg
# start saving
# Processing image: .//testB/035733B.jpg
# start saving
# Processing image: .//testB/025674B.jpg
# start saving
# Processing image: .//testB/033604B.jpg
# start saving
# Processing image: .//testB/024366B.jpg
# start saving
# Processing image: .//testB/029516B.jpg
# start saving
# Processing image: .//testB/027039B.jpg
# start saving
# Processing image: .//testB/034551B.jpg
# start saving
# Processing image: .//testB/039045B.jpg
# start saving
# Processing image: .//testB/012101B.jpg
# start saving
# Processing image: .//testB/025972B.jpg
# start saving
# Processing image: .//testB/019161B.jpg
# start saving
# Processing image: .//testB/023019B.jpg
# start saving
# Processing image: .//testB/018429B.jpg
# start saving
# Processing image: .//testB/037961B.jpg
# start saving
# Processing image: .//testB/024030B.jpg
# start saving
# Processing image: .//testB/024820B.jpg
# start saving
# Processing image: .//testB/039961B.jpg
# start saving
# Processing image: .//testB/025593B.jpg
# start saving
# Processing image: .//testB/014429B.jpg
# start saving
# Processing image: .//testB/033688B.jpg
# start saving
# Processing image: .//testB/027491B.jpg
# start saving
# Processing image: .//testB/023189B.jpg
# start saving
# Processing image: .//testB/006397B.jpg
# start saving
# Processing image: .//testB/019768B.jpg
# start saving
# Processing image: .//testB/033640B.jpg
# start saving
# Processing image: .//testB/026647B.jpg
# start saving
# Processing image: .//testB/024523B.jpg
# start saving
# Processing image: .//testB/030063B.jpg
# start saving
# Processing image: .//testB/014233B.jpg
# start saving
# Processing image: .//testB/023103B.jpg
# start saving
# Processing image: .//testB/037037B.jpg
# start saving
# Processing image: .//testB/027016B.jpg
# start saving
# Processing image: .//testB/037450B.jpg
# start saving
# Processing image: .//testB/039544B.jpg
# start saving
# Processing image: .//testB/025048B.jpg
# start saving
# Processing image: .//testB/005877B.jpg
# start saving
# Processing image: .//testB/021070B.jpg
# start saving
# Processing image: .//testB/006217B.jpg
# start saving
# Processing image: .//testB/040459B.jpg
# start saving
# Processing image: .//testB/037912B.jpg
# start saving
# Processing image: .//testB/016097B.jpg
# start saving
# Processing image: .//testB/020116B.jpg
# start saving
# Processing image: .//testB/025460B.jpg
# start saving
# Processing image: .//testB/034326B.jpg
# start saving
# Processing image: .//testB/037319B.jpg
# start saving
# Processing image: .//testB/024711B.jpg
# start saving
# Processing image: .//testB/021963B.jpg
# start saving
# Processing image: .//testB/015971B.jpg
# start saving
# Processing image: .//testB/034146B.jpg
# start saving
# Processing image: .//testB/000720B.jpg
# start saving
# Processing image: .//testB/037169B.jpg
# start saving
# Processing image: .//testB/033586B.jpg
# start saving
# Processing image: .//testB/021918B.jpg
# start saving
# Processing image: .//testB/021636B.jpg
# start saving
# Processing image: .//testB/018079B.jpg
# start saving
# Processing image: .//testB/025021B.jpg
# start saving
# Processing image: .//testB/022617B.jpg
# start saving
# Processing image: .//testB/037203B.jpg
# start saving
# Processing image: .//testB/029827B.jpg
# start saving
# Processing image: .//testB/035072B.jpg
# start saving
# Processing image: .//testB/020052B.jpg
# start saving
# Processing image: .//testB/026393B.jpg
# start saving
# Processing image: .//testB/018186B.jpg
# start saving
# Processing image: .//testB/023238B.jpg
# start saving
# Processing image: .//testB/031615B.jpg
# start saving
# Processing image: .//testB/038054B.jpg
# start saving
# Processing image: .//testB/019126B.jpg
# start saving
# Processing image: .//testB/025854B.jpg
# start saving
# Processing image: .//testB/022751B.jpg
# start saving
# Processing image: .//testB/033369B.jpg
# start saving
# Processing image: .//testB/011987B.jpg
# start saving
# Processing image: .//testB/035482B.jpg
# start saving
# Processing image: .//testB/004581B.jpg
# start saving
# Processing image: .//testB/021239B.jpg
# start saving
# Processing image: .//testB/033310B.jpg
# start saving
# Processing image: .//testB/029563B.jpg
# start saving
# Processing image: .//testB/023060B.jpg
# start saving
# Processing image: .//testB/036952B.jpg
# start saving
# Processing image: .//testB/025913B.jpg
# start saving
# Processing image: .//testB/036010B.jpg
# start saving
# Processing image: .//testB/033468B.jpg
# start saving
# Processing image: .//testB/022514B.jpg
# start saving
# Processing image: .//testB/026846B.jpg
# start saving
# Processing image: .//testB/024634B.jpg
# start saving
# Processing image: .//testB/028786B.jpg
# start saving
# Processing image: .//testB/021659B.jpg
# start saving
# Processing image: .//testB/037789B.jpg
# start saving
# Processing image: .//testB/009601B.jpg
# start saving
# Processing image: .//testB/003973B.jpg
# start saving
# Processing image: .//testB/025831B.jpg
# start saving
# Processing image: .//testB/022943B.jpg
# start saving
# Processing image: .//testB/039238B.jpg
# start saving
# Processing image: .//testB/036993B.jpg
# start saving
# Processing image: .//testB/035636B.jpg
# start saving
# Processing image: .//testB/023682B.jpg
# start saving
# Processing image: .//testB/026905B.jpg
# start saving
# Processing image: .//testB/024839B.jpg
# start saving
# Processing image: .//testB/036966B.jpg
# start saving
# Processing image: .//testB/004547B.jpg
# start saving
# Processing image: .//testB/005955B.jpg
# start saving
# Processing image: .//testB/028917B.jpg
# start saving
# Processing image: .//testB/003959B.jpg
# start saving
# Processing image: .//testB/037965B.jpg
# start saving
# Processing image: .//testB/015993B.jpg
# start saving
# Processing image: .//testB/039829B.jpg
# start saving
# Processing image: .//testB/020605B.jpg
# start saving
# Processing image: .//testB/025167B.jpg
# start saving
# Processing image: .//testB/029164B.jpg
# start saving
# Processing image: .//testB/027819B.jpg
# start saving
# Processing image: .//testB/012002B.jpg
# start saving
# Processing image: .//testB/037916B.jpg
# start saving
# Processing image: .//testB/024688B.jpg
# start saving
# Processing image: .//testB/004733B.jpg
# start saving
# Processing image: .//testB/022645B.jpg
# start saving
# Processing image: .//testB/032110B.jpg
# start saving
# Processing image: .//testB/037884B.jpg
# start saving
# Processing image: .//testB/025525B.jpg
# start saving
# Processing image: .//testB/039323B.jpg
# start saving
# Processing image: .//testB/008936B.jpg
# start saving
# Processing image: .//testB/018954B.jpg
# start saving
# Processing image: .//testB/030598B.jpg
# start saving
# Processing image: .//testB/039138B.jpg
# start saving
# Processing image: .//testB/024873B.jpg
# start saving
# Processing image: .//testB/025588B.jpg
# start saving
# Processing image: .//testB/032642B.jpg
# start saving
# Processing image: .//testB/029209B.jpg
# start saving
# Processing image: .//testB/022467B.jpg
# start saving
# Processing image: .//testB/033070B.jpg
# start saving
# Processing image: .//testB/033562B.jpg
# start saving
# Processing image: .//testB/038831B.jpg
# start saving
# Processing image: .//testB/018128B.jpg
# start saving
# Processing image: .//testB/040271B.jpg
# start saving
# Processing image: .//testB/006676B.jpg
# start saving
# Processing image: .//testB/039748B.jpg
# start saving
# Processing image: .//testB/025818B.jpg
# start saving
# Processing image: .//testB/018048B.jpg
# start saving
# Processing image: .//testB/033302B.jpg
# start saving
# Processing image: .//testB/038128B.jpg
# start saving
# Processing image: .//testB/038518B.jpg
# start saving
# Processing image: .//testB/030507B.jpg
# start saving
# Processing image: .//testB/039942B.jpg
# start saving
# Processing image: .//testB/019052B.jpg
# start saving
# Processing image: .//testB/026151B.jpg
# start saving
# Processing image: .//testB/018190B.jpg
# start saving
# Processing image: .//testB/015203B.jpg
# start saving
# Processing image: .//testB/012799B.jpg
# start saving
# Processing image: .//testB/007078B.jpg
# start saving
# Processing image: .//testB/026955B.jpg
# start saving
# Processing image: .//testB/037848B.jpg
# start saving
# Processing image: .//testB/022942B.jpg
# start saving
# Processing image: .//testB/030014B.jpg
# start saving
# Processing image: .//testB/005960B.jpg
# start saving
# Processing image: .//testB/019649B.jpg
# start saving
# Processing image: .//testB/022568B.jpg
# start saving
# Processing image: .//testB/016060B.jpg
# start saving
# Processing image: .//testB/027035B.jpg
# start saving
# Processing image: .//testB/025848B.jpg
# start saving
# Processing image: .//testB/039377B.jpg
# start saving
# Processing image: .//testB/025221B.jpg
# start saving
# Processing image: .//testB/039817B.jpg
# start saving
# Processing image: .//testB/038031B.jpg
# start saving
# Processing image: .//testB/019453B.jpg
# start saving
# Processing image: .//testB/029119B.jpg
# start saving
# Processing image: .//testB/036741B.jpg
# start saving
# Processing image: .//testB/026768B.jpg
# start saving
